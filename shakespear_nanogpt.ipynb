# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 16 # indep sequences processed in parallel
block_size = 32 # maximum context length for preds

max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(torch.cuda.is_available())

eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)
# Out:
# False

# %%
# read file
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
print("length of dataset in characters: ", len(text))

# first 1000 chars
print(text[:1000])
# Out:
# --2025-02-19 20:28:48--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt’
#
# input.txt           100%[===================>]   1.06M  --.-KB/s    in 0.05s
#
# 2025-02-19 20:28:48 (20.2 MB/s) - ‘input.txt’ saved [1115394/1115394]
#
# length of dataset in characters:  1115394
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# You are all resolved rather to die than to famish?
#
# All:
# Resolved. resolved.
#
# First Citizen:
# First, you know Caius Marcius is chief enemy to the people.
#
# All:
# We know't, we know't.
#
# First Citizen:
# Let us kill him, and we'll have corn at our own price.
# Is't a verdict?
#
# All:
# No more talking on't; let it be done: away, away!
#
# Second Citizen:
# One word, good citizens.
#
# First Citizen:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us: if they
# would yield us but the superfluity, while it were
# wholesome, we might guess they relieved us humanely;
# but they think we are too dear: the leanness that
# afflicts us, the object of our misery, is as an
# inventory to particularise their abundance; our
# sufferance is a gain to them Let us revenge this with
# our pikes, ere we become rakes: for the gods know I
# speak this in hunger for bread, not in thirst for revenge.

# %%
chars = sorted(list(set(text))) # unique chars
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# 65

# %%
# mapping ()
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # str -> int
decode = lambda l: ''.join([itos[i] for i in l]) # int -> str

print(encode("hii there"))
print(decode(encode("hii there")))
# Out:
# [46, 47, 47, 1, 58, 46, 43, 56, 43]
# hii there

# %%
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000])
# Out:
# torch.Size([1115394]) torch.int64
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 14, 43, 44,
#         53, 56, 43,  1, 61, 43,  1, 54, 56, 53, 41, 43, 43, 42,  1, 39, 52, 63,
#          1, 44, 59, 56, 58, 46, 43, 56,  6,  1, 46, 43, 39, 56,  1, 51, 43,  1,
#         57, 54, 43, 39, 49,  8,  0,  0, 13, 50, 50, 10,  0, 31, 54, 43, 39, 49,
#          6,  1, 57, 54, 43, 39, 49,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47,
#         58, 47, 64, 43, 52, 10,  0, 37, 53, 59,  1, 39, 56, 43,  1, 39, 50, 50,
#          1, 56, 43, 57, 53, 50, 60, 43, 42,  1, 56, 39, 58, 46, 43, 56,  1, 58,
#         53,  1, 42, 47, 43,  1, 58, 46, 39, 52,  1, 58, 53,  1, 44, 39, 51, 47,
#         57, 46, 12,  0,  0, 13, 50, 50, 10,  0, 30, 43, 57, 53, 50, 60, 43, 42,
#          8,  1, 56, 43, 57, 53, 50, 60, 43, 42,  8,  0,  0, 18, 47, 56, 57, 58,
#          1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 18, 47, 56, 57, 58,  6,  1, 63,
#         53, 59,  1, 49, 52, 53, 61,  1, 15, 39, 47, 59, 57,  1, 25, 39, 56, 41,
#         47, 59, 57,  1, 47, 57,  1, 41, 46, 47, 43, 44,  1, 43, 52, 43, 51, 63,
#          1, 58, 53,  1, 58, 46, 43,  1, 54, 43, 53, 54, 50, 43,  8,  0,  0, 13,
#         50, 50, 10,  0, 35, 43,  1, 49, 52, 53, 61,  5, 58,  6,  1, 61, 43,  1,
#         49, 52, 53, 61,  5, 58,  8,  0,  0, 18, 47, 56, 57, 58,  1, 15, 47, 58,
#         47, 64, 43, 52, 10,  0, 24, 43, 58,  1, 59, 57,  1, 49, 47, 50, 50,  1,
#         46, 47, 51,  6,  1, 39, 52, 42,  1, 61, 43,  5, 50, 50,  1, 46, 39, 60,
#         43,  1, 41, 53, 56, 52,  1, 39, 58,  1, 53, 59, 56,  1, 53, 61, 52,  1,
#         54, 56, 47, 41, 43,  8,  0, 21, 57,  5, 58,  1, 39,  1, 60, 43, 56, 42,
#         47, 41, 58, 12,  0,  0, 13, 50, 50, 10,  0, 26, 53,  1, 51, 53, 56, 43,
#          1, 58, 39, 50, 49, 47, 52, 45,  1, 53, 52,  5, 58, 11,  1, 50, 43, 58,
#          1, 47, 58,  1, 40, 43,  1, 42, 53, 52, 43, 10,  1, 39, 61, 39, 63,  6,
#          1, 39, 61, 39, 63,  2,  0,  0, 31, 43, 41, 53, 52, 42,  1, 15, 47, 58,
#         47, 64, 43, 52, 10,  0, 27, 52, 43,  1, 61, 53, 56, 42,  6,  1, 45, 53,
#         53, 42,  1, 41, 47, 58, 47, 64, 43, 52, 57,  8,  0,  0, 18, 47, 56, 57,
#         58,  1, 15, 47, 58, 47, 64, 43, 52, 10,  0, 35, 43,  1, 39, 56, 43,  1,
#         39, 41, 41, 53, 59, 52, 58, 43, 42,  1, 54, 53, 53, 56,  1, 41, 47, 58,
#         47, 64, 43, 52, 57,  6,  1, 58, 46, 43,  1, 54, 39, 58, 56, 47, 41, 47,
#         39, 52, 57,  1, 45, 53, 53, 42,  8,  0, 35, 46, 39, 58,  1, 39, 59, 58,
#         46, 53, 56, 47, 58, 63,  1, 57, 59, 56, 44, 43, 47, 58, 57,  1, 53, 52,
#          1, 61, 53, 59, 50, 42,  1, 56, 43, 50, 47, 43, 60, 43,  1, 59, 57, 10,
#          1, 47, 44,  1, 58, 46, 43, 63,  0, 61, 53, 59, 50, 42,  1, 63, 47, 43,
#         50, 42,  1, 59, 57,  1, 40, 59, 58,  1, 58, 46, 43,  1, 57, 59, 54, 43,
#         56, 44, 50, 59, 47, 58, 63,  6,  1, 61, 46, 47, 50, 43,  1, 47, 58,  1,
#         61, 43, 56, 43,  0, 61, 46, 53, 50, 43, 57, 53, 51, 43,  6,  1, 61, 43,
#          1, 51, 47, 45, 46, 58,  1, 45, 59, 43, 57, 57,  1, 58, 46, 43, 63,  1,
#         56, 43, 50, 47, 43, 60, 43, 42,  1, 59, 57,  1, 46, 59, 51, 39, 52, 43,
#         50, 63, 11,  0, 40, 59, 58,  1, 58, 46, 43, 63,  1, 58, 46, 47, 52, 49,
#          1, 61, 43,  1, 39, 56, 43,  1, 58, 53, 53,  1, 42, 43, 39, 56, 10,  1,
#         58, 46, 43,  1, 50, 43, 39, 52, 52, 43, 57, 57,  1, 58, 46, 39, 58,  0,
#         39, 44, 44, 50, 47, 41, 58, 57,  1, 59, 57,  6,  1, 58, 46, 43,  1, 53,
#         40, 48, 43, 41, 58,  1, 53, 44,  1, 53, 59, 56,  1, 51, 47, 57, 43, 56,
#         63,  6,  1, 47, 57,  1, 39, 57,  1, 39, 52,  0, 47, 52, 60, 43, 52, 58,
#         53, 56, 63,  1, 58, 53,  1, 54, 39, 56, 58, 47, 41, 59, 50, 39, 56, 47,
#         57, 43,  1, 58, 46, 43, 47, 56,  1, 39, 40, 59, 52, 42, 39, 52, 41, 43,
#         11,  1, 53, 59, 56,  0, 57, 59, 44, 44, 43, 56, 39, 52, 41, 43,  1, 47,
#         57,  1, 39,  1, 45, 39, 47, 52,  1, 58, 53,  1, 58, 46, 43, 51,  1, 24,
#         43, 58,  1, 59, 57,  1, 56, 43, 60, 43, 52, 45, 43,  1, 58, 46, 47, 57,
#          1, 61, 47, 58, 46,  0, 53, 59, 56,  1, 54, 47, 49, 43, 57,  6,  1, 43,
#         56, 43,  1, 61, 43,  1, 40, 43, 41, 53, 51, 43,  1, 56, 39, 49, 43, 57,
#         10,  1, 44, 53, 56,  1, 58, 46, 43,  1, 45, 53, 42, 57,  1, 49, 52, 53,
#         61,  1, 21,  0, 57, 54, 43, 39, 49,  1, 58, 46, 47, 57,  1, 47, 52,  1,
#         46, 59, 52, 45, 43, 56,  1, 44, 53, 56,  1, 40, 56, 43, 39, 42,  6,  1,
#         52, 53, 58,  1, 47, 52,  1, 58, 46, 47, 56, 57, 58,  1, 44, 53, 56,  1,
#         56, 43, 60, 43, 52, 45, 43,  8,  0,  0])

# %%
# train/test split (90-10)
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([18, 47, 56, 57, 58,  1, 15, 47, 58])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([18]) the target: 47
# when input is tensor([18, 47]) the target: 56
# when input is tensor([18, 47, 56]) the target: 57
# when input is tensor([18, 47, 56, 57]) the target: 58
# when input is tensor([18, 47, 56, 57, 58]) the target: 1
# when input is tensor([18, 47, 56, 57, 58,  1]) the target: 15
# when input is tensor([18, 47, 56, 57, 58,  1, 15]) the target: 47
# when input is tensor([18, 47, 56, 57, 58,  1, 15, 47]) the target: 58

# %%
# 
def get_batch(split):
    # generate small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)

print('----')

for b in range(batch_size):
    for t in range(block_size):
        context = xb[b, :t+1]
        target = yb[b, t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([16, 8])
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54],
#         [57, 43, 60, 43, 52,  1, 63, 43],
#         [60, 43, 42,  8,  0, 25, 63,  1],
#         [56, 42,  5, 57,  1, 57, 39, 49],
#         [43, 57, 58, 63,  6,  1, 58, 46],
#         [43,  1, 51, 39, 63,  1, 40, 43],
#         [58, 46, 43,  1, 43, 39, 56, 57],
#         [39, 58, 47, 53, 52, 12,  1, 37],
#         [53, 56, 43,  1, 21,  1, 41, 39],
#         [50, 39, 52, 63,  1, 47, 58, 57],
#         [56, 53, 63,  1, 42, 47, 42,  1],
#         [39, 51,  1, 39, 44, 56, 39, 47],
#         [17, 24, 21, 38, 13, 14, 17, 32]])
# targets:
# torch.Size([16, 8])
# tensor([[43, 58,  5, 57,  1, 46, 43, 39],
#         [53, 56,  1, 58, 46, 39, 58,  1],
#         [58,  1, 58, 46, 39, 58,  1, 46],
#         [17, 27, 10,  0, 21,  1, 54, 39],
#         [43, 60, 43, 52,  1, 63, 43, 39],
#         [43, 42,  8,  0, 25, 63,  1, 45],
#         [42,  5, 57,  1, 57, 39, 49, 43],
#         [57, 58, 63,  6,  1, 58, 46, 47],
#         [ 1, 51, 39, 63,  1, 40, 43,  1],
#         [46, 43,  1, 43, 39, 56, 57, 10],
#         [58, 47, 53, 52, 12,  1, 37, 53],
#         [56, 43,  1, 21,  1, 41, 39, 51],
#         [39, 52, 63,  1, 47, 58, 57, 43],
#         [53, 63,  1, 42, 47, 42,  1, 57],
#         [51,  1, 39, 44, 56, 39, 47, 42],
#         [24, 21, 38, 13, 14, 17, 32, 20]])
# ----
# when input is [24] the target: 43
# when input is [24, 43] the target: 58
# when input is [24, 43, 58] the target: 5
# when input is [24, 43, 58, 5] the target: 57
# when input is [24, 43, 58, 5, 57] the target: 1
# when input is [24, 43, 58, 5, 57, 1] the target: 46
# when input is [24, 43, 58, 5, 57, 1, 46] the target: 43
# when input is [24, 43, 58, 5, 57, 1, 46, 43] the target: 39
# when input is [44] the target: 53
# when input is [44, 53] the target: 56
# when input is [44, 53, 56] the target: 1
# when input is [44, 53, 56, 1] the target: 58
# when input is [44, 53, 56, 1, 58] the target: 46
# when input is [44, 53, 56, 1, 58, 46] the target: 39
# when input is [44, 53, 56, 1, 58, 46, 39] the target: 58
# when input is [44, 53, 56, 1, 58, 46, 39, 58] the target: 1
# when input is [52] the target: 58
# when input is [52, 58] the target: 1
# when input is [52, 58, 1] the target: 58
# when input is [52, 58, 1, 58] the target: 46
# when input is [52, 58, 1, 58, 46] the target: 39
# when input is [52, 58, 1, 58, 46, 39] the target: 58
# when input is [52, 58, 1, 58, 46, 39, 58] the target: 1
# when input is [52, 58, 1, 58, 46, 39, 58, 1] the target: 46
# when input is [25] the target: 17
# when input is [25, 17] the target: 27
# when input is [25, 17, 27] the target: 10
# when input is [25, 17, 27, 10] the target: 0
# when input is [25, 17, 27, 10, 0] the target: 21
# when input is [25, 17, 27, 10, 0, 21] the target: 1
# when input is [25, 17, 27, 10, 0, 21, 1] the target: 54
# when input is [25, 17, 27, 10, 0, 21, 1, 54] the target: 39
# when input is [57] the target: 43
# when input is [57, 43] the target: 60
# when input is [57, 43, 60] the target: 43
# when input is [57, 43, 60, 43] the target: 52
# when input is [57, 43, 60, 43, 52] the target: 1
# when input is [57, 43, 60, 43, 52, 1] the target: 63
# when input is [57, 43, 60, 43, 52, 1, 63] the target: 43
# when input is [57, 43, 60, 43, 52, 1, 63, 43] the target: 39
# when input is [60] the target: 43
# when input is [60, 43] the target: 42
# when input is [60, 43, 42] the target: 8
# when input is [60, 43, 42, 8] the target: 0
# when input is [60, 43, 42, 8, 0] the target: 25
# when input is [60, 43, 42, 8, 0, 25] the target: 63
# when input is [60, 43, 42, 8, 0, 25, 63] the target: 1
# when input is [60, 43, 42, 8, 0, 25, 63, 1] the target: 45
# when input is [56] the target: 42
# when input is [56, 42] the target: 5
# when input is [56, 42, 5] the target: 57
# when input is [56, 42, 5, 57] the target: 1
# when input is [56, 42, 5, 57, 1] the target: 57
# when input is [56, 42, 5, 57, 1, 57] the target: 39
# when input is [56, 42, 5, 57, 1, 57, 39] the target: 49
# when input is [56, 42, 5, 57, 1, 57, 39, 49] the target: 43
# when input is [43] the target: 57
# when input is [43, 57] the target: 58
# when input is [43, 57, 58] the target: 63
# when input is [43, 57, 58, 63] the target: 6
# when input is [43, 57, 58, 63, 6] the target: 1
# when input is [43, 57, 58, 63, 6, 1] the target: 58
# when input is [43, 57, 58, 63, 6, 1, 58] the target: 46
# when input is [43, 57, 58, 63, 6, 1, 58, 46] the target: 47
# when input is [43] the target: 1
# when input is [43, 1] the target: 51
# when input is [43, 1, 51] the target: 39
# when input is [43, 1, 51, 39] the target: 63
# when input is [43, 1, 51, 39, 63] the target: 1
# when input is [43, 1, 51, 39, 63, 1] the target: 40
# when input is [43, 1, 51, 39, 63, 1, 40] the target: 43
# when input is [43, 1, 51, 39, 63, 1, 40, 43] the target: 1
# when input is [58] the target: 46
# when input is [58, 46] the target: 43
# when input is [58, 46, 43] the target: 1
# when input is [58, 46, 43, 1] the target: 43
# when input is [58, 46, 43, 1, 43] the target: 39
# when input is [58, 46, 43, 1, 43, 39] the target: 56
# when input is [58, 46, 43, 1, 43, 39, 56] the target: 57
# when input is [58, 46, 43, 1, 43, 39, 56, 57] the target: 10
# when input is [39] the target: 58
# when input is [39, 58] the target: 47
# when input is [39, 58, 47] the target: 53
# when input is [39, 58, 47, 53] the target: 52
# when input is [39, 58, 47, 53, 52] the target: 12
# when input is [39, 58, 47, 53, 52, 12] the target: 1
# when input is [39, 58, 47, 53, 52, 12, 1] the target: 37
# when input is [39, 58, 47, 53, 52, 12, 1, 37] the target: 53
# when input is [53] the target: 56
# when input is [53, 56] the target: 43
# when input is [53, 56, 43] the target: 1
# when input is [53, 56, 43, 1] the target: 21
# when input is [53, 56, 43, 1, 21] the target: 1
# when input is [53, 56, 43, 1, 21, 1] the target: 41
# when input is [53, 56, 43, 1, 21, 1, 41] the target: 39
# when input is [53, 56, 43, 1, 21, 1, 41, 39] the target: 51
# when input is [50] the target: 39
# when input is [50, 39] the target: 52
# when input is [50, 39, 52] the target: 63
# when input is [50, 39, 52, 63] the target: 1
# when input is [50, 39, 52, 63, 1] the target: 47
# when input is [50, 39, 52, 63, 1, 47] the target: 58
# when input is [50, 39, 52, 63, 1, 47, 58] the target: 57
# when input is [50, 39, 52, 63, 1, 47, 58, 57] the target: 43
# when input is [56] the target: 53
# when input is [56, 53] the target: 63
# when input is [56, 53, 63] the target: 1
# when input is [56, 53, 63, 1] the target: 42
# when input is [56, 53, 63, 1, 42] the target: 47
# when input is [56, 53, 63, 1, 42, 47] the target: 42
# when input is [56, 53, 63, 1, 42, 47, 42] the target: 1
# when input is [56, 53, 63, 1, 42, 47, 42, 1] the target: 57
# when input is [39] the target: 51
# when input is [39, 51] the target: 1
# when input is [39, 51, 1] the target: 39
# when input is [39, 51, 1, 39] the target: 44
# when input is [39, 51, 1, 39, 44] the target: 56
# when input is [39, 51, 1, 39, 44, 56] the target: 39
# when input is [39, 51, 1, 39, 44, 56, 39] the target: 47
# when input is [39, 51, 1, 39, 44, 56, 39, 47] the target: 42
# when input is [17] the target: 24
# when input is [17, 24] the target: 21
# when input is [17, 24, 21] the target: 38
# when input is [17, 24, 21, 38] the target: 13
# when input is [17, 24, 21, 38, 13] the target: 14
# when input is [17, 24, 21, 38, 13, 14] the target: 17
# when input is [17, 24, 21, 38, 13, 14, 17] the target: 32
# when input is [17, 24, 21, 38, 13, 14, 17, 32] the target: 20

# %%
print(xb) # input to transformer
# Out:
# tensor([[24, 43, 58,  5, 57,  1, 46, 43],
#         [44, 53, 56,  1, 58, 46, 39, 58],
#         [52, 58,  1, 58, 46, 39, 58,  1],
#         [25, 17, 27, 10,  0, 21,  1, 54],
#         [57, 43, 60, 43, 52,  1, 63, 43],
#         [60, 43, 42,  8,  0, 25, 63,  1],
#         [56, 42,  5, 57,  1, 57, 39, 49],
#         [43, 57, 58, 63,  6,  1, 58, 46],
#         [43,  1, 51, 39, 63,  1, 40, 43],
#         [58, 46, 43,  1, 43, 39, 56, 57],
#         [39, 58, 47, 53, 52, 12,  1, 37],
#         [53, 56, 43,  1, 21,  1, 41, 39],
#         [50, 39, 52, 63,  1, 47, 58, 57],
#         [56, 53, 63,  1, 42, 47, 42,  1],
#         [39, 51,  1, 39, 44, 56, 39, 47],
#         [17, 24, 21, 38, 13, 14, 17, 32]])

# %%
@torch.no_grad() # memory optimization
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
torch.manual_seed(1337)
B,T,C = 4,8,2
x = torch.randn(B,T,C)
x.shape
# Out:
# torch.Size([4, 8, 2])

# %%
xbow = torch.zeros((B,T,C))
for b in range(B):
    for t in range(T):
        xprev = x[b, :t+1] # (t,C)
        xbow[b, t] = torch.mean(xprev, 0)

# %%
# version 2
wei = torch.tril(torch.ones(T, T))
wei = wei / wei.sum(1, keepdim=True)
xbow2 = wei @ x # ((B), T, T) @ (B, T, C) = (B, T, C)
torch.allclose(xbow,xbow2)
# Out:
# False

# %%
# version 3: Softmax
tril = torch.tril((torch.ones(T, T)))
wei = torch.zeros(T, T)
wei = wei.masked_fill(tril==0, float("-inf"))
wei = F.softmax(wei, dim=-1)
xbow3 = wei @ x
torch.allclose(xbow2, xbow3)
# Out:
# True

# %%
# version 4: self-attention
torch.manual_seed(1337)
B,T,C = 4,8,32 # batch, time, channel
x = torch.randn(B,T,C) # "private information to this token"

# single Head perform self-attention
head_size = 16 # hyperparameter
key = nn.Linear(C, head_size, bias=False)
query = nn.Linear(C, head_size, bias=False)
value = nn.Linear(C, head_size, bias=False)

k = key(x) # (B, T, head_size); 
q = query(x) # (B, T, head_size)
wei = q @ k.transpose(-2, -1) # (B, T, head_size) @ (B, head_size, T) = (B, T, T) -> contains affinities

tril = torch.tril((torch.ones(T, T)))
#wei = torch.zeros(T, T)
wei = wei.masked_fill(tril==0, float("-inf"))
wei = F.softmax(wei, dim=-1)

v = value(x)
out = wei @ v

out.shape
# Out:
# torch.Size([4, 8, 16])

# %%
torch.tril(torch.ones(3,3))
# Out:
# tensor([[1., 0., 0.],
#         [1., 1., 0.],
#         [1., 1., 1.]])

# %%
torch.manual_seed(42)
a = torch.tril(torch.ones(3,3))
a = a / torch.sum(a, 1, keepdim=True)
print(a)
b = torch.randint(0,10,(3,2)).float()
c = a @ b
print(c)
# Out:
# tensor([[1.0000, 0.0000, 0.0000],
#         [0.5000, 0.5000, 0.0000],
#         [0.3333, 0.3333, 0.3333]])
# tensor([[2.0000, 7.0000],
#         [4.0000, 5.5000],
#         [4.6667, 5.3333]])

# %%
class LayerNorm1d: 

  def __init__(self, dim, eps=1e-5, momentum=0.1):
    self.eps = eps
    self.gamma = torch.ones(dim)
    self.beta = torch.zeros(dim)

  def __call__(self, x):
    # calculate the forward pass
    xmean = x.mean(1, keepdim=True) # batch mean
    xvar = x.var(1, keepdim=True) # batch variance
    xhat = (x - xmean) / torch.sqrt(xvar + self.eps) # norm to var=1
    self.out = self.gamma * xhat + self.beta
    return self.out

  def parameters(self): # learned parameters
    return [self.gamma, self.beta] 

torch.manual_seed(1337)
module = LayerNorm1d(100)
x = torch.randn(32, 100) # batch size 32 of 100-dim vectors
x = module(x)
x.shape
# Out:
# torch.Size([32, 100])

# %%
class Head(nn.Module):
    # single head of self-attention
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)

        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x) # (B,T,C)
        q = self.query(x) # (B,T,C)

        # compute attention scores - affinities
        wei = q @ k.transpose(-2, -1) * C**-0.5 # (B, T, head_size) @ (B, head_size, T) = (B, T, T); divided by sqrt(channel_dim)
        #wei = torch.zeros(T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        # v: weighted aggregation of values
        v = self.value(x)  # (B, T, T) @ (B, T, C) -> (B, T, C)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):
    # multiple heads
    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    # linear layer with ReLU at the end
    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            
        )
    def forward(self, x):
        return self.net(x)
   

class Block(nn.Module):
    # Transformer block
    
    def __init__(self, n_embd, n_head):
        # n_embd: embedding dim
        # n_head: num of heads
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        # deep network -> optimization: residual blocks (based on https://arxiv.org/pdf/1512.03385v1)
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x
        

class BigramLanguageModel(nn.Module):
    
    def __init__(self):
        super().__init__()

        
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=4) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)

    
    def forward(self, idx, targets=None):
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx) # (B, T, C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T, C)
        x = tok_emb + pos_emb # (B, T, C)
        x = self.blocks(x) # (B ,T, C)
        x = self.ln_f(x) # (B, T, C)
        logits = self.lm_head(x) # (B, T, vocab_size) -

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]

            # get preds
            logits, loss = self(idx_cond)
            
            # focus on last time step
            logits = logits[:, -1, :] # becomes (B, C)
            
            # apply softmax to get probs
            probs = F.softmax(logits, dim=-1) # (B, C)
            
            # sample from distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            
            # append sampled index to the running index
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx
        
        
# m = BigramLanguageModel(vocab_size)
# logits, loss = m(xb, yb)
# print(logits.shape)
# print(loss)

# print(decode(m.generate(idx = torch.zeros((1, 1), dtype=torch.long), max_new_tokens=100)[0].tolist()))

# %%
model = BigramLanguageModel()
m = model.to(device)

# print num of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

optimizer = torch.optim.AdamW(m.parameters(), lr=learning_rate)

for iter in range(max_iters):

    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch
    xb, yb = get_batch('train')

    # eval the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# 0.208193 M parameters
# step 0: train loss 4.2903, val loss 4.2821
# step 100: train loss 2.7193, val loss 2.7257
# step 200: train loss 2.5494, val loss 2.5536
# step 300: train loss 2.4750, val loss 2.4635
# step 400: train loss 2.3898, val loss 2.3738
# step 500: train loss 2.3741, val loss 2.3624
# step 600: train loss 2.3242, val loss 2.3262
# step 700: train loss 2.3006, val loss 2.2921
# step 800: train loss 2.2460, val loss 2.2628
# step 900: train loss 2.2349, val loss 2.2291
# step 1000: train loss 2.1936, val loss 2.2110
# step 1100: train loss 2.2017, val loss 2.2011
# step 1200: train loss 2.1847, val loss 2.2041
# step 1300: train loss 2.1820, val loss 2.1863
# step 1400: train loss 2.1446, val loss 2.1892
# step 1500: train loss 2.1300, val loss 2.1513
# step 1600: train loss 2.1299, val loss 2.1560
# step 1700: train loss 2.1034, val loss 2.1305
# step 1800: train loss 2.1213, val loss 2.1567
# step 1900: train loss 2.0944, val loss 2.1640
# step 2000: train loss 2.0787, val loss 2.1256
# step 2100: train loss 2.0622, val loss 2.1415
# step 2200: train loss 2.0677, val loss 2.1043
# step 2300: train loss 2.0404, val loss 2.1112
# step 2400: train loss 2.0243, val loss 2.1040
# step 2500: train loss 2.0475, val loss 2.1153
# step 2600: train loss 2.0316, val loss 2.0958
# step 2700: train loss 2.0258, val loss 2.1044
# step 2800: train loss 2.0261, val loss 2.0944
# step 2900: train loss 1.9991, val loss 2.0892
# step 3000: train loss 2.0000, val loss 2.0710
# step 3100: train loss 1.9860, val loss 2.0623
# step 3200: train loss 1.9950, val loss 2.0632
# step 3300: train loss 1.9885, val loss 2.0875
# step 3400: train loss 1.9807, val loss 2.0532
# step 3500: train loss 1.9765, val loss 2.0728
# step 3600: train loss 1.9903, val loss 2.0623
# step 3700: train loss 1.9687, val loss 2.0649
# step 3800: train loss 1.9608, val loss 2.0451
# step 3900: train loss 1.9443, val loss 2.0727
# step 4000: train loss 1.9567, val loss 2.0426
# step 4100: train loss 1.9338, val loss 2.0441
# step 4200: train loss 1.9508, val loss 2.0430
# step 4300: train loss 1.9407, val loss 2.0174
# step 4400: train loss 1.9398, val loss 2.0400
# step 4500: train loss 1.9194, val loss 2.0418
# step 4600: train loss 1.9548, val loss 2.0532
# step 4700: train loss 1.9161, val loss 2.0249
# step 4800: train loss 1.9175, val loss 2.0437
# step 4900: train loss 1.9243, val loss 2.0606
# step 4999: train loss 1.9213, val loss 2.0575

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=5000)[0].tolist()))
# Out:
# First to my, more, to mustoret the pure 'tis ange pity her be mad;
# A repare aber mare a brother stre,
# As nongoa
# wath ewnem bolcomes me.
#
# NARD A:
# Erdly not mady 'It stwer mul idre, at sir, and a York perfollo lord;
# not seelf have fendly bear us rears a deard our Rome.
# Bin of it thing cime men,
# Is no, as a from is cktedd ir bear king most enatir:
# Not feacl vicious' my good hut not preted of up jes
# My mrich ut pril,
# That'd lord as than deepear chelp?
# Fround hertub,
# The thine frull; ple.
#
# YOR HENRY I lruch of am proved us a bence for this after.
#
# PELIZENE:
# Nour lord
# And his's, bear this me.
# and to were
# se, us my hothin to defale let me py moaliny sogR my betcaus do be storge a ard reash, sirry, in the and feaplalf?- I owell be with? dito tho famen as is band tibleed sir, blesseustih Duy all-dee;
# First trution. our a well you have lapid, in the would at; thou kiry to nawpett lord meyre your doyd ever her kind a would a geal:
# O, Girst af in hible vicked welt douse th brothrach, evancy cea bectrought I teat my light not te markort
# For mut hear the my worst the may of hosett: ameo but to good; our whrivids,
# That your be old ther hith the gainsir him strome, nein!
#
# ESCAKILHEN:
# My brother sufls,
# As in inacewell with your
# Prindoge; And at ated
# I to swald of my sport; with wish i' mem, for the lord, it pratord
# When in the pace on rack? Dears sid?
#
# QEEN CAPULELEZEN:
# Hall dold mutty me, lord.
#
# CAPULET:
# HAMINIUS:
# I heep thee hiye of sout a deadaster to diemitis air that or hith come,
# And be fortike fidis of bay, he mut wram
# On eis broting is rusicted, gen ine be death, yould
# is with and but
# Pirly.
#
# CLORIONCENTEN:
# He kin of ce for pursilozer, Lords mine your pake lis gind the purs spet their throuk trrund he we ditandy?
#
# BRRY CAKINCK:
# At, not can:
# The me? I leard be bocettly one wrowich a bown? my was fais you his all reventroy,
# I thrued cesple had pmost.
# Corscore I sprost to hee,
# Havens hee a affells bide ic make righter stefen; and brear;
# BR--
# Meast agair worth, fe rathange,
# And himb mek, tear'd I fird,
# I wing you tear vick me nan mosust so prevaning trive, your wi but sury Raulown.
# There's.
#
# AMPER!
#
# MARGARECK:
# Co, this fraps rome, and and steav
# The sur her must loughtly!-
# Fir all have him;
# Brust? dring to Lightly we death till 'Ks benep
# Kid
# Citiour be.
#
# MEN RICHARICK:
# Are's pore an therk'd man, and mpal not in see for pardeers adve voin:
# He as ravost hidourd'd rederry, uble a welloung of wilth will a
# Right.I
#
# HERMAR:
# Tith par havy comets! you heold crace a mudered um is a bery indeld deeter new, struch,
# Sir lieve you per Rome of I gind, or much surn,
# I rused EdY thip, are blots a pound nruls, dother, meni cing.
#
# HENRY But harm'd it by trump you fall of thild, this fe?
#
# GLOUCESTER: 's 'btling.
# WhiE stay;
# Fet who, 'nd-cester warlong, no mire in bunpayd op ston un sirty--s: well death and rutil well
# aners this speen, fear if mictlance hear youf Xork, minesge indo tithe have doy, all so ame buchant a mace, yor ould feats.
#
# GLOUCESTER:
# My on all meels. Which Reciol.
# Whoth, no.
#
# HENRY VI!
# First in mune's
# Rewis is nonie, but he fave lard and forance, thard a sHars
# he may be but heir spein rast sivet: a kiny to hip gooke peicher as mallure he kin man! And sir, her 'tis grainiin dog sir;
# Fir lur
# Thire dap.
# -
#
# CLIF RA3
#
# K: up if uas her's gur oun lord; not uselly fie: fity if much sume!
# O st that feal ever my say a frear more mea boinion
# He or but thee it hit womp you life, year mardorribl
# Bhands her!
#
# MINVIOLUS:
# I lempled sul't her to repfor thre drulh, a sheak nit, of ceffance rade buld to him,--hip?
#
# DUKE OF OF IONENE:
# Dio, Redes, your thy the thange bear man: the sell the peace not self, your mangue
# Twonds e wen is of stering you poste to chesse to,
# A mall, old3 geath; se,
# My Etwn thou serving, tilly filtbrother'd truch,
# O, leem us nob will not us or lords,
# Feen Musicher
# To buts our are be blike,--
# Whance reby spe murghan: thou ftal ce.
# HarR'd baffecram of the wim doyivost: dead, my nest we rie but I sellivence blog earfutil subloy be't like eartorr; silly,
# As appill to
# were nother Purpprop blood's toly?
#
# QRGILOLAURENCES:
# Nir hum, inle of Mecter as lesseed what'dt spead up hears
# An would alfair.
# Framan on a her opto Withen erry sprace bed rark, at they buch so,
# brothun'd that life I
# Henry, ling him fawer peain frie
# thin solding, thour se fethavibiok.
#
# CAMERLARD IZnhare art the Dosth of with parfor lord;
# Diy the father how flile merly,
# Marmself of yehar beeten us to dum,
# His all prom--
# Me fadiout up, sor, and 'pon well firl
# On him.
#
# BROKElNout
# Yet baling reas wouft
#
# DUIVEr:
# King dry my carst.
# Ting, mall'd may sir his she folage,
# But comper set would repell I thereand,
# Nir I kning beamorse't sit, tork he heard!
#
# FWORMEARD:
# It smo mefful inture, that it one buoch,--The down, deephere strustipiny,
# But not we sal I fairst my sporie me unless,
# Nirst a jurst forth kinseran: in the me sak, a that dlo fore a as and but to-mer.
#
# PLolBRO:
# Hat, but the kind shall in I were
# For rick, then enestrah:
# Wate, cie, are jurd a bethat gre what wi
